# %% [markdown]
# # **Soal No 1**

# %%
import numpy as np

# %%
# Buat matrix X berukuran 2x3 menggunakan numpy
x = np.array([[23, 9, 6],
              [25, 61, 110]])
x
# Out:
# array([[ 23,   9,   6],
#        [ 25,  61, 110]])

# %%
# Tampilkan ukuran dari matrix X
x.shape
# Out:
# (2, 3)

# %%
# Tampilkan seluruh elemen dari KOLOM PERTAMA dari matrix X
x[:, 0]
# Out:
# array([23, 25])

# %%
# Tampilkan seluruh elemen dari BARIS KEDUA dari matrix X
x[1, :]
# Out:
# array([ 25,  61, 110])

# %% [markdown]
# # **Soal No 2**

# %% [markdown]
# Ulangi soal nomor 1 menggunakan PYTORCH

# %%
import torch

# %%
# Buat matrix X berukuran 2x3 menggunakan pytorch
x_pt = torch.tensor([[23, 9, 6],
              [25, 61, 110]])
x_pt
# Out:
# tensor([[ 23,   9,   6],
#         [ 25,  61, 110]])

# %%
# Tampilkan ukuran dari matrix X
x_pt.shape
# Out:
# torch.Size([2, 3])

# %%
# Tampilkan seluruh elemen dari KOLOM PERTAMA dari matrix X
x_pt[:, 0]
# Out:
# tensor([23, 25])

# %%
# Tampilkan seluruh elemen dari BARIS KEDUA dari matrix X
x_pt[1, :]
# Out:
# tensor([ 25,  61, 110])

# %% [markdown]
# Ulangi soal nomor 1 menggunakan TENSORFLOW

# %%
import tensorflow as tf

# %%
# Buat matrix X berukuran 2x3 menggunakan tensorflow
x_tf = tf.Variable([[23, 9, 6],
              [25, 61, 110]])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[ 23,   9,   6],
#        [ 25,  61, 110]], dtype=int32)>

# %%
# Tampilkan ukuran dari matrix X
x_tf.shape
# Out:
# TensorShape([2, 3])

# %%
# Tampilkan seluruh elemen dari KOLOM PERTAMA dari matrix X
x_tf[:, 0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([23, 25], dtype=int32)>

# %%
# Tampilkan seluruh elemen dari BARIS KEDUA dari matrix X
x_tf[1, :]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([ 25,  61, 110], dtype=int32)>

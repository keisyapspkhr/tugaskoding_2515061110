# %% [markdown]
# # **Soal no.1**
# Selesaikan soal berikut
# ![Cuplikan layar 2026-04-12 234815.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
x = np.array([[25],
              [2],
              [-3],
              [-25]])
x
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-25]])

# %%
x_transpose = x.T
x_transpose
# Out:
# array([[ 25,   2,  -3, -25]])

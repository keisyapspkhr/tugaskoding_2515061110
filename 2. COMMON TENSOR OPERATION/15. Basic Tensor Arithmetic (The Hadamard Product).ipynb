# %%
import numpy as np
import torch
import tensorflow as tf

# %% [markdown]
# # **Soal No. 1**

# %%
# Buat matrix X dengan ukuran 2x3 menggunakan NUMPY
X = np.array([[23, 9, 6], [25, 15, 11]])
X
# Out:
# array([[23,  9,  6],
#        [25, 15, 11]])

# %%
# Buat matrix X_pt dengan ukuran 2x3 menggunakan PYTORCH
X_pt = torch.tensor([[2, 3, 9], [2, 5, 6]])
X_pt
# Out:
# tensor([[2, 3, 9],
#         [2, 5, 6]])

# %%
# Buat matrix X_tf dengan ukuran 2x3 menggunakan TENSORFLOW
X_tf = tf.Variable([[9, 6, 23], [15, 61, 11]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[ 9,  6, 23],
#        [15, 61, 11]], dtype=int32)>

# %% [markdown]
# Lakukan perkalian matrix X, X_pt dan X_tf dengan suatu skalar

# %%
X*2
# Out:
# array([[46, 18, 12],
#        [50, 30, 22]])

# %%
X_pt*2
# Out:
# tensor([[ 4,  6, 18],
#         [ 4, 10, 12]])

# %%
X_tf*2
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[ 18,  12,  46],
#        [ 30, 122,  22]], dtype=int32)>

# %% [markdown]
# Lakukan penjumlahan matrix X, X_pt dan X_tf dengan suatu skalar

# %%
X+3
# Out:
# array([[26, 12,  9],
#        [28, 18, 14]])

# %%
X_pt+3
# Out:
# tensor([[ 5,  6, 12],
#         [ 5,  8,  9]])

# %%
X_tf+3
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[12,  9, 26],
#        [18, 64, 14]], dtype=int32)>

# %% [markdown]
# Lakukan pengurangan matrix X, X_pt dan X_tf dengan suatu skalar

# %%
X-4
# Out:
# array([[19,  5,  2],
#        [21, 11,  7]])

# %%
X_pt-4
# Out:
# tensor([[-2, -1,  5],
#         [-2,  1,  2]])

# %%
X_tf-4
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[ 5,  2, 19],
#        [11, 57,  7]], dtype=int32)>

# %% [markdown]
# # **Soal No.2**

# %%
# Buat matrix Y dengan ukuran 2x3 menggunakan NUMPY
Y = np.array([[2, 3, 9], [2, 5, 1]])
Y
# Out:
# array([[2, 3, 9],
#        [2, 5, 1]])

# %%
# Buat matrix Y_pt dengan ukuran 2x3 menggunakan PYTORCH
Y_pt = torch.tensor([[9, 6, 23], [15, 61, 11]])
Y_pt
# Out:
# tensor([[ 9,  6, 23],
#         [15, 61, 11]])

# %%
# Buat matrix Y_tf dengan ukuran 2x3 menggunakan TENSORFLOW
Y_tf = tf.Variable([[2, 3, 4], (21, 20, 26)])
Y_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[ 2,  3,  4],
#        [21, 20, 26]], dtype=int32)>

# %%
# Kalikan matrix X dengan Y
X*Y
# Out:
# array([[46, 27, 54],
#        [50, 75, 11]])

# %%
# Kalikan matrix X_pt tdengan Y_pt
X_pt*Y_pt
# Out:
# tensor([[ 18,  18, 207],
#         [ 30, 305,  66]])

# %%
# Kalikan matrix X_tf dengan Y_tf
X_tf*Y_tf
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[  18,   18,   92],
#        [ 315, 1220,  286]], dtype=int32)>

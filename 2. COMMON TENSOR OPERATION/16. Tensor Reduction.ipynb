# %%
import numpy as np
import torch
import tensorflow as tf

# %% [markdown]
# # **Soal No 1**

# %%
# Buat matrix X dengan ukuran 2x3 menggunakan NUMPY
X = np.array([[25, 15, 110], [61, 23, 9]])
X
# Out:
# array([[ 25,  15, 110],
#        [ 61,  23,   9]])

# %%
# Hitung beberapa hasil penjumlahan elemen matrix X dengan fungsi sum
X.sum()
# Out:
# np.int64(243)

# %%
# Buat matrix X_tf dengan ukuran 2x3 menggunakan TENSORFLOW
X_tf = tf.Variable([[2, 5, 11], [5, 6, 1]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[ 2,  5, 11],
#        [ 5,  6,  1]], dtype=int32)>

# %% [markdown]
# # **Soal No 2**

# %%
# Hitung hasil PENJUMLAHAN seluruh elemen matrix X
np.sum(X)
# Out:
# np.int64(253)

# %%
# Hitung hasil PENJUMLAHAN seluruh elemen matrix X_pt
X_pt = torch.tensor([[20, 6, 23], [25, 61, 11]])
X_pt
# Out:
# tensor([[20,  6, 23],
#         [25, 61, 11]])

# %%
torch.sum(X_pt)
# Out:
# tensor(146)

# %%
# Hitung hasil PENJUMLAHAN seluruh elemen matrix X_tf
tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=30>

# %% [markdown]
# # **Soal No 3**

# %%
# Hitung hasil penjumlahan matrix X berdasarkan ROW nya
X.sum(axis=0)
# Out:
# array([ 86,  38, 119])

# %%
# Hitung hasil penjumlahan matrix X_pt berdasarkan ROW nya
torch.sum(X_pt, 0)
# Out:
# tensor([45, 67, 34])

# %%
# Hitung hasil penjumlahan matrix X_tf berdasarkan ROW nya
tf.reduce_sum(X_tf, 0)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([ 7, 11, 12], dtype=int32)>

# %% [markdown]
# # **Soal No 4**

# %%
# Hitung hasil penjumlahan matrix X berdasarkan KOLOM nya
X.sum(axis=1)
# Out:
# array([150,  93])

# %%
# Hitung hasil penjumlahan matrix X_pt berdasarkan KOLOM nya
torch.sum(X_pt, 1)
# Out:
# tensor([49, 97])

# %%
# Hitung hasil penjumlahan matrix X_tf berdasarkan KOLOM nya
tf.reduce_sum(X_tf, 1)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([18, 12], dtype=int32)>

# %% [markdown]
# # **Soal No 5**

# %% [markdown]
# Hitung nilai MINIMAL dari matrix X, X_pt, X_tf

# %%
X.min()
# Out:
# np.int64(9)

# %%
X_pt.min()
# Out:
# tensor(6)

# %%
tf.reduce_min(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %% [markdown]
# Hitung nilai MAKSIMAL dari matrix X, X_pt, X_tf

# %%
X.max()
# Out:
# np.int64(110)

# %%
X_pt.max()
# Out:
# tensor(61)

# %%
tf.reduce_max(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=11>

# %% [markdown]
# Hitung nilai RATA RATA dari matrix X, X_pt, X_tf

# %%
X.mean()
# Out:
# np.float64(40.5)

# %%
X_pt.float().mean()
# Out:
# tensor(24.3333)

# %%
tf.reduce_mean(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=5>

# %% [markdown]
# # **Soal No 6**

# %%
# Hitung hasil PERKALIAN sleuruh elemen X
X.prod()
# Out:
# np.int64(520863750)

# %%
# Hitung hasil PERKALIAN sleuruh elemen X_pt
torch.prod(X_pt)
# Out:
# tensor(46299000)

# %%
# Hitung hasil PERKALIAN sleuruh elemen X_tf
tf.reduce_prod(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=3300>
